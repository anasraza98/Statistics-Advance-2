# %% [markdown]
# #Statistics Part-2
#
#
# 1. What is hypothesis testing in statistics?
#
#   - Hypothesis testing is a statistical method used to make decisions about a population based on sample data. It involves formulating a null hypothesis and an alternative hypothesis, and using sample evidence to decide which hypothesis is more likely to be true.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
#   - Null Hypothesis (H₀): Assumes no effect or no difference.
#
#   - Alternative Hypothesis (H₁ or Ha): Assumes there is an effect or difference.
#   They are mutually exclusive, rejecting one implies accepting the other.
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#
#   - The significance level (α) is the probability of rejecting the null hypothesis when it is actually true (Type I error). Common values are 0.05 or 0.01. It defines the threshold for statistical significance.
#
# 4. What does a P-value represent in hypothesis testing?
#
#   - A P-value indicates the probability of obtaining results as extreme as the observed data, assuming the null hypothesis is true.
#
# 5. How do you interpret the P-value in hypothesis testing?
#
#   - Low P-value (≤ α): Reject H₀ (evidence supports H₁).
#
#   - High P-value (> α): Fail to reject H₀ (insufficient evidence for H₁).
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
#   - Type I Error: Rejecting H₀ when it is true (false positive).
#
#   - Type II Error: Failing to reject H₀ when it is false (false negative).
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
#   - One-tailed test: Tests for deviation in one direction (e.g, greater than).
#
#   - Two-tailed test: Tests for deviation in both directions (e.g, not equal to).
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
#   - A Z-test is used when the population variance is known and the sample size is large (n > 30). It tests the mean difference or proportion difference using the Z-distribution.
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
#   - Z-score = (X̄ - μ) / (σ / √n)
#   It measures how many standard deviations a sample mean is from the population mean.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
#   - The T-distribution is used when the sample size is small (n < 30) and population standard deviation is unknown. It accounts for more variability than the normal distribution.
#
# 11. What is the difference between a Z-test and a T-test?
#
#   - Z-test: Known variance, large sample.
#
#   - T-test: Unknown variance, small sample.
#   T-test uses the T-distribution, Z-test uses the normal distribution.
#
# 12. What is the T-test, and how is it used in hypothesis testing?
#
#   - A T-test compares means between groups or with a known value when population variance is unknown. Types:
#   * One-sample
#
#   * Two-sample (independent)
#
#   * Paired sample
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
#   - Both test hypotheses about means, but the Z-test assumes known variance and larger samples, while the T-test accounts for estimation of variance and is used with smaller samples.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
#   - A confidence interval (CI) gives a range of values likely to contain the population parameter. For example, a 95% CI suggests 95% confidence that the true mean lies within the interval.
#
# 15. What is the margin of error, and how does it affect the confidence interval?
#
#   - Margin of Error is the range added/subtracted from a sample statistic to create the CI. A larger margin leads to a wider CI, indicating less precision.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
#   - Bayes' Theorem updates the probability of a hypothesis based on new evidence. It's widely used in decision-making, machine learning, and Bayesian inference.
#
# 17. What is the Chi-square distribution, and when is it used?
#
#   - The Chi-square distribution is used for categorical data. It is applied in tests of independence and goodness of fit.
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
#   - This test checks if observed frequencies match expected frequencies. It's used to test if a distribution follows a specific pattern.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
#   - The F-distribution is used to compare variances. It's key in ANOVA and F-tests for testing model fits and variances.
#
# 20. What is an ANOVA test, and what are its assumptions?
#
#   - ANOVA (Analysis of Variance) compares means across 3 or more groups.
#   - Assumptions:
#
#   * Independence
#   * Normality
#   * Equal variances (homogeneity)
#
# 21. What are the different types of ANOVA tests?
#
#   - One-way ANOVA: One independent variable.
#
#   - Two-way ANOVA: Two independent variables.
#
#   - Repeated Measures ANOVA: Same subjects tested multiple times.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
#   - The F-test compares two variances or model fits. It's used in ANOVA and regression analysis to determine if differences are statistically significant.

# %%
#-------------------------------Practical Part - 1------------------------------------

#1. Write a Python program to generate a random variable and display its value.

import numpy as np

random_var = np.random.rand()
print("Random Variable:", random_var)
# Out:
# Random Variable: 0.21479056301235122

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import matplotlib.pyplot as plt
from scipy.stats import randint

x = range(1, 7)
pmf = randint.pmf(x, 1, 7)

plt.stem(x, pmf)
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

from scipy.stats import bernoulli

def bernoulli_pdf(p):
    x = [0, 1]
    pdf = bernoulli.pmf(x, p)
    return dict(zip(x, pdf))

print(bernoulli_pdf(0.6))
# Out:
# {0: np.float64(0.4000000000000001), 1: np.float64(0.6)}

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

binom_data = np.random.binomial(n=10, p=0.5, size=1000)

plt.hist(binom_data, bins=11, edgecolor='black')
plt.title("Binomial Distribution Histogram (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %%
#5. Create a Poisson distribution and visualize it using Python.

from scipy.stats import poisson

x = np.arange(0, 15)
pmf = poisson.pmf(x, mu=4)

plt.stem(x, pmf)
plt.title("Poisson Distribution (λ = 4)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()

# %%
#6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
#   uniform distribution.
cdf = randint.cdf(x, 1, 7)

plt.step(x, cdf, where="post")
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.show()

# %%
#7. Generate a continuous uniform distribution using NumPy and visualize it.

cont_uniform = np.random.uniform(low=0.0, high=1.0, size=1000)

plt.hist(cont_uniform, bins=30, edgecolor='black')
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
#8. Simulate data from a normal distribution and plot its histogram.

normal_data = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(normal_data, bins=30, edgecolor='black')
plt.title("Normal Distribution Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.

from scipy.stats import zscore

data = np.random.normal(loc=50, scale=10, size=1000)
z_scores = zscore(data)

plt.hist(z_scores, bins=30, edgecolor='black')
plt.title("Z-score Histogram")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %%
#10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

sample_means = []

for _ in range(1000):
    sample = np.random.exponential(scale=2.0, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black')
plt.title("Central Limit Theorem (CLT) Demonstration")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %%
#11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

sample_means = []
for _ in range(1000):
    sample = np.random.normal(loc=0, scale=1, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black')
plt.title("CLT Verification with Normal Samples")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

from scipy.stats import norm

x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x, 0, 1)

plt.plot(x, pdf)
plt.title("Standard Normal Distribution")
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid()
plt.show()

# %%
#13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n+1)
probs = binom.pmf(x, n, p)

for val, prob in zip(x, probs):
    print(f"P(X={val}) = {prob:.4f}")
# Out:
# P(X=0) = 0.0010
# P(X=1) = 0.0098
# P(X=2) = 0.0439
# P(X=3) = 0.1172
# P(X=4) = 0.2051
# P(X=5) = 0.2461
# P(X=6) = 0.2051
# P(X=7) = 0.1172
# P(X=8) = 0.0439
# P(X=9) = 0.0098
# P(X=10) = 0.0010

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
#  distribution.

def calc_z_score(x, mean, std):
    return (x - mean) / std

z = calc_z_score(75, 70, 5)
print(f"Z-score: {z}")
# Out:
# Z-score: 1.0

# %%
#15. Implement hypothesis testing using Z-statistics for a sample dataset.

from scipy.stats import norm

sample_mean = 52
pop_mean = 50
std_dev = 5
n = 30

z = (sample_mean - pop_mean) / (std_dev / np.sqrt(n))
p_value = 1 - norm.cdf(z)

print("Z-statistic:", z)
print("P-value:", p_value)
# Out:
# Z-statistic: 2.1908902300206643
# P-value: 0.014229868458155326

# %%
#16. Create a confidence interval for a dataset using Python and interpret the result.

import scipy.stats as stats

data = np.random.normal(loc=100, scale=10, size=50)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)

print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (np.float64(98.62504367205815), np.float64(104.13584931456359))

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

data = np.random.normal(60, 8, 100)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)

print(f"Mean: {mean}, 95% CI: {ci}")
# Out:
# Mean: 60.044699993137336, 95% CI: (np.float64(58.563363346219674), np.float64(61.526036640055))

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the parameters for the normal distribution
mean = 0
std_dev = 1

# Generate x values
x = np.linspace(-4, 4, 1000)

# Calculate the actual PDF using scipy's norm.pdf
pdf_values = norm.pdf(x, loc=mean, scale=std_dev)

# Plot the PDF
plt.plot(x, pdf_values, label='Normal PDF')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('PDF')
plt.grid(True)
plt.legend()
plt.show()

# %%
#19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

x = np.arange(0, 15)
cdf = poisson.cdf(x, mu=4)

plt.step(x, cdf, where="post")
plt.title("CDF of Poisson Distribution")
plt.xlabel("x")
plt.ylabel("CDF")
plt.show()

# %%
#20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

data = np.random.uniform(10, 20, 1000)
expected_value = np.mean(data)
print("Expected Value:", expected_value)
# Out:
# Expected Value: 14.964415456481307

# %%
#21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

data1 = np.random.normal(50, 5, 1000)
data2 = np.random.normal(50, 10, 1000)

print("Std Dev 1:", np.std(data1))
print("Std Dev 2:", np.std(data2))

plt.hist(data1, alpha=0.5, label='Low Variance')
plt.hist(data2, alpha=0.5, label='High Variance')
plt.legend()
plt.show()
# Out:
# Std Dev 1: 4.861543819431748
# Std Dev 2: 9.707846660468912

# %%
#22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

data = np.random.normal(0, 1, 1000)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print("Range:", np.ptp(data))
print("IQR:", iqr)
# Out:
# Range: 6.869085759861294
# IQR: 1.3213013341652848

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation.

data = np.random.normal(100, 15, 100)
normalized = (data - np.mean(data)) / np.std(data)

plt.hist(normalized, bins=30, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.show()

# %%
#24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.08278312096763922
# Kurtosis: 0.027871822235122412

# %%
#---------------------------------------PRACTICAL PART-2---------------------------------

#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results.

from scipy import stats
import numpy as np

sample = [102, 100, 98, 105, 101]
pop_mean = 100

z_stat, p_val = stats.ttest_1samp(sample, pop_mean)
print(f"Z-statistic: {z_stat}, P-value: {p_val}")
# Out:
# Z-statistic: 1.0366421106976345, P-value: 0.3584563446229633

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=100)
pop_mean = 52

z_stat, p_val = stats.ttest_1samp(sample, pop_mean)
print(f"P-value: {p_val}")
# Out:
# P-value: 2.41447601360673e-07

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

from statsmodels.stats.weightstats import ztest

sample = np.array([102, 100, 98, 105, 101])
z_stat, p_val = ztest(sample, value=100)
print(f"Z-statistic: {z_stat}, P-value: {p_val}")
# Out:
# Z-statistic: 1.0366421106976345, P-value: 0.2999026801669571

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

import matplotlib.pyplot as plt
from scipy.stats import norm

z_stat, p_val = ztest(sample, value=100)
x = np.linspace(-4, 4, 1000)
plt.plot(x, norm.pdf(x), label='Standard Normal')
plt.axvline(x=z_stat, color='red', linestyle='--', label='Z-statistic')
plt.fill_between(x, 0, norm.pdf(x), where=(abs(x) > abs(z_stat)), color='red', alpha=0.2)
plt.legend()
plt.title("Two-tailed Z-test")
plt.show()

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

def visualize_type_errors(mu0=100, mu1=102, sigma=10, n=30, alpha=0.05):
    from scipy.stats import norm

    se = sigma / np.sqrt(n)
    z_alpha = norm.ppf(1 - alpha)
    critical_value = mu0 + z_alpha * se

    x = np.linspace(mu0 - 3*se, mu1 + 3*se, 1000)
    y0 = norm.pdf(x, mu0, se)
    y1 = norm.pdf(x, mu1, se)

    plt.plot(x, y0, label="H0")
    plt.plot(x, y1, label="H1")
    plt.axvline(x=critical_value, color='red', linestyle='--', label='Critical value')

    plt.fill_between(x, 0, y1, where=(x < critical_value), color='orange', alpha=0.3, label='Type II error')
    plt.fill_between(x, 0, y0, where=(x > critical_value), color='blue', alpha=0.3, label='Type I error')

    plt.legend()
    plt.title("Type I and II Errors")
    plt.show()

visualize_type_errors()

# %%
#6. Write a Python program to perform an independent T-test and interpret the results.

group1 = np.random.normal(50, 5, 30)
group2 = np.random.normal(52, 5, 30)

t_stat, p_val = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat}, P-value: {p_val}")
# Out:
# T-statistic: -1.0918409928429156, P-value: 0.279417753118556

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results.

before = np.random.normal(100, 10, 30)
after = before + np.random.normal(-2, 5, 30)

t_stat, p_val = stats.ttest_rel(before, after)
print(f"T-statistic: {t_stat}, P-value: {p_val}")
# Out:
# T-statistic: 0.9851848900978829, P-value: 0.33268199944406107

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

data = np.random.normal(100, 10, 30)

z_stat, p_z = ztest(data, value=100)
t_stat, p_t = stats.ttest_1samp(data, 100)

print(f"Z-test: Z={z_stat}, P={p_z}")
print(f"T-test: T={t_stat}, P={p_t}")
# Out:
# Z-test: Z=-0.15718887548403135, P=0.8750959953909916
# T-test: T=-0.15718887548403135, P=0.8761853050923207

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    sem = stats.sem(data)
    margin = sem * stats.t.ppf((1 + confidence) / 2., n-1)
    return mean - margin, mean + margin

ci = confidence_interval(data)
print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(95.65425872676381), np.float64(103.7254212219648))

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

def margin_of_error(data, confidence=0.95):
    sem = stats.sem(data)
    moe = sem * stats.t.ppf((1 + confidence) / 2., len(data) - 1)
    return moe

print("Margin of Error:", margin_of_error(data))
# Out:
# Margin of Error: 4.035581247600485

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

def bayes_theorem(prior_A, prob_B_given_A, prob_B_given_not_A):
    prob_not_A = 1 - prior_A
    prob_B = prob_B_given_A * prior_A + prob_B_given_not_A * prob_not_A
    posterior = (prob_B_given_A * prior_A) / prob_B
    return posterior

print("Posterior probability:", bayes_theorem(0.01, 0.9, 0.05))
# Out:
# Posterior probability: 0.15384615384615385

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python.

import pandas as pd
from scipy.stats import chi2_contingency

data = [[10, 20, 30], [6, 9, 17]]
chi2, p, dof, ex = chi2_contingency(data)
print(f"Chi-square: {chi2}, P-value: {p}")
# Out:
# Chi-square: 0.27157465150403504, P-value: 0.873028283380073

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
#  data.

observed = np.array([[10, 20, 30], [6, 9, 17]])
_, _, _, expected = chi2_contingency(observed)
print("Expected frequencies:\n", expected)
# Out:
# Expected frequencies:
#  [[10.43478261 18.91304348 30.65217391]
#  [ 5.56521739 10.08695652 16.34782609]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

observed = [20, 30, 50]
expected = [25, 25, 50]

chi2, p = stats.chisquare(f_obs=observed, f_exp=expected)
print(f"Chi-square: {chi2}, P-value: {p}")
# Out:
# Chi-square: 2.0, P-value: 0.36787944117144245
